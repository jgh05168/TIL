# %% [markdown]
# Grid System
#
# - Bootsstrap Grid system
#
#     - 개요
#
#     - Grid system 클래스와 기보 구조
#
# - Grid system for responsive web
#
#     - 개요
#
#     - Grid system Breakpoints
#
# [참고]
#
# ```html
# ul.nav>li.nav-item*4>a{메뉴 $}
# ```
#
# => 한 줄에 블록을 작성할 수도 있다.
#
# emmet cheat sheet 검색 후 docs 확인해보기

# %% [markdown]
# ## Bootstrap Grid system
#
# : 웹 페이지의 레이아웃을 조정하는 데 사용되는 **12개의 column**으로 구성된 시스템
#
# 목적 : 반응형 디자인을 지원해 웹페이지를 다양한 기기에서 적절하게 표시할 수 있도록 도움
#
# ### Grid system 기본 요소
#
# 1. Container : Column들을 담고 있는 공간
#
# 2. Column : 실제 컨텐츠를 포함하는 부분
#
# 3. Gutter : 컬럼과 컬럼 사이의 여백 영역
#
#     - Grid system에서 column 사이에 여백 영역
#
#     - x 축은 padding, y 축은 margin으로 여백 생성
#
#     - g-* : 상하좌우 | gx-* : 좌우 | gy-* : 상하
#
# <br>
#
# ```html
# <!-- 기본 구조 -->
# <div class="container">
#     <div class="row">
#         <div class="col-4"></div>
#         <div class="col-4"></div>
#         <div class="col-4"></div>
#     </div>
# </div>
# ```

# %% [markdown]
# <br>
#
# ## Grid system Responsive Web
#
# : 디바이스 종류나 화면 크기에 상관없이, 어디서든 일관된 레이아웃 및 사용자 경험을 제공하는 웹
#
# - 12개의 column과 **6개의 breakpoints**를 사용하여 반응형 웹 디자인을 구현
#
# ### Grid system breakpoints
#
# : 웹 페이지를 다양한 화면 크기에서 적절하게 배치하기 위한 분기점
#
# -> 화면  너비에 따라 6개의 분기점 제공 : xs, sm, md, lg, xl, xxl
#
# |/|xs<576px|sm>=576px|md>=768px|lg>=992px|xl>=1200px|xxl>=1400px|
# |--|--|--|--|--|--|--|
# |Container(max-width)|None(auto)|540px|720px|960px|1140px|1320px|
# |Class prefix|.col-|.col-sm-|.col-md-|.col-lg-|.col-xl-|.col-xxl-|
#
# : 각 breakpoints 마다 설정된 최대 너비 값 "이상으로" 화면이 커지면 grid system 동작이 변경된다.
#
# : 각 범위들은 **~ 이상** 임을 잊지 말자! -> 이하일 경우도 설정해주어야 한다.

# %% [markdown]
# <br>
#
# 정리:
#
# 1. 어떤 레이아웃 기술이 사용되었는가 ?
#
#     position, flex, grid system 등등
#
# #### 큰 틀을 우선 잡고, 각각의 상황에 맞는 기술 사용
#
# <br>
#
# [참고]
#
# - CSS가 아닌 편집 디자인에서 나온 개념으로 구성 요소를 잘 배치해서 시각적을 좋은 결과물을 만들기 위함
#
# - 기본적으로 안쪽에 있는 요소들의 오와 열을 맞ㅊ는 것에서 기인
#
# - 정보 구조와 배열을 체계적으로 작성하여 정보의 질서를 부여하는 시스템
#
# ![image.png](attachment:image.png)
#
# Grid cards : 클래스를 사용하여 행 당 표시할 열 수를 손쉽게 제어할 수 있음
#
#     - Grid card의 경우 주도권이 행한테 있음
#
#     - bootstrap의 cards 맨 마지막 부분을 참고
